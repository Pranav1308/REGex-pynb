# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib notebook

# %%
data = np.arange(10)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(data,data)

# %%
fig = plt.figure(figsize = (6,6)) #intialization of figure
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
p1 = fig.add_subplot(2,2,1)
p2 = fig.add_subplot(2,2,2)    #this command intializes subplots on the figure
p3 = fig.add_subplot(2,2,3)    #there should be n variables like p1,p2,p3,p4 because we have given 2,2 argument i.e along the row and along the column
p4 = fig.add_subplot(2,2,4)    #in short multiply first 2 arguments and there should be that much variables
#first argument is along row and second is along the column and the third one is kind of index to remembre the pllot no.

# %%
p1.plot(np.arange(10), 'k-')  #here k is the black colour and - indicates simple line

# %%
p2.scatter(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
p3.plot(np.arange(10), 'm--')

# %%
p4.plot(np.arange(10), 'co-')

# %%
fig, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes[0].plot(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
axes[1].scatter(np.arange(30), np.arange(30) + np.random.randn(30))

# %%
plt.figure()
x = np.arange(10)
y = np.arange(10)
plt.plot(x,y, 'r-*')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize = (5,5))
plt.plot(np.random.randn(30), 'mo-', label = 'FirstPlot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple line plot')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.figure()
x = np.arange(10)
y = x ** 2
z = x ** 3
plt.plot(x,y, 'm*-', label = 'Squares')
plt.plot(x,z, 'bo-', label = 'Cubes')
plt.title('Squares and Cubes')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
x = np.arange(10)
y = x ** 2
plt.scatter(x,y, s = 100, c = 'm')# c is colour and s is size
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xticks(np.arange(10))
# Out:
# ([<matplotlib.axis.XTick at 0x20c058fbdc0>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9')])

# %%
plt.yticks(np.arange(0,100,5))
# Out:
# ([<matplotlib.axis.YTick at 0x20c058fed60>,
# ...
#  [Text(0, -10.0, '−10'),
#   Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60'),
#   Text(0, 70.0, '70'),
#   Text(0, 80.0, '80'),
#   Text(0, 90.0, '90'),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.arange(10)
y = x * 2
plt.bar(x,y, width = 0.8)
plt.xticks(x)
plt.yticks(y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.YTick at 0x20c02c512e0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.arange(10)
y = x * 2
z = x * 4
plt.bar(x,y, width = 0.4, color = 'm')
plt.bar(x,z, width = 0.4, color = 'orange', bottom = x)#if we dont write bottom  = x then the orange command will be shown only it will get stacked on each other to avodi that the bottom command is used
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 10 artists>

# %%
plt.figure()
x = np.arange(10)
y = x * 2
z = x * 4
plt.bar(x-0.2,y, width = 0.4, color = 'm')
plt.bar(x+0.3,z, width = 0.4, color = 'c')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 10 artists>

# %%
plt.figure()
plt.hist([1,2,3,4,5,4,2,3,4,5,8,9] , width = 0.6)
plt.xticks(range(10))
plt.yticks(range(5))
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.YTick at 0x20c0be86850>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure()
x = np.random.normal(100,10,500)
plt.hist(x)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  2.,   7.,  25.,  54., 120., 115., 100.,  49.,  24.,   4.]),
#  array([ 63.43986175,  70.22276658,  77.00567141,  83.78857624,
#          90.57148107,  97.3543859 , 104.13729073, 110.92019556,
#         117.7031004 , 124.48600523, 131.26891006]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure()
x = np.array([10,30,20,15,25])
plt.pie(x)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x20c0db8e430>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(-5.149471629032507e-08, 1.0999999999999988, ''),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, ''),
#   Text(-0.49938943041996464, -0.9801072373902886, ''),
#   Text(0.7778175685419842, -0.777817350068405, '')])

# %%
plt.figure()
x = np.array([10,30,20,15,25])
food = ['Bananas', 'Small Bananas', 'Big Bananas', 'Oranges', 'Big Oranges']
plt.pie(x, labels = food)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x20c0e6cca60>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'Bananas'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, 'Small Bananas'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Big Bananas'),
#   Text(-0.49938943041996464, -0.9801072373902886, 'Oranges'),
#   Text(0.7778175685419842, -0.777817350068405, 'Big Oranges')])

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3068/3793406994.py in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
